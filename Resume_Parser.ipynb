# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshita2012/Financial-Advisory/blob/main/Resume_Parser.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install resume-parser
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 2.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 35.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.0/58.0 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.6/2.6 MB 40.7 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 44.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 58.4 MB/s eta 0:00:00
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3960 sha256=88cab36080d35b161cda02dadcc99fa27d7e0f2fdd42ca28b7e34a907107d9d0
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# ...

# %%
import pandas as pd

# %%
# !pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
# !pip install importlib-metadata==3.2.0
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 39.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 369.2/369.2 kB 35.3 MB/s eta 0:00:00
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.3.1-py3-none-any.whl size=12047086 sha256=1e1ddce8615d2924f5babd568f5ea8a8a84e83ddb7bf554e246b82fd75e6913d
#   Stored in directory: /root/.cache/pip/wheels/4f/1f/0e/16fae4b01d2d87454e0f484e58c48793efcf237f0894c1c4bd
# Successfully built en-core-web-sm
# ...
#   Attempting uninstall: wasabi
#     Found existing installation: wasabi 1.1.3
#     Uninstalling wasabi-1.1.3:
#       Successfully uninstalled wasabi-1.1.3
#   Attempting uninstall: srsly
#     Found existing installation: srsly 2.4.8
#     Uninstalling srsly-2.4.8:
# ...

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# !pip install pyresparser
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 56.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.7/117.7 kB 12.4 MB/s eta 0:00:00
# ...

# %%
from pyresparser import ResumeParser
import warnings

# %%
warnings.filterwarnings("ignore", category=UserWarning)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data = ResumeParser('/content/drive/MyDrive/Resume parsing resumes/Alka Katariya Resume.pdf').get_extracted_data()
print(data)
# Out:
# {'name': 'Alka Katariya', 'email': 'alkakatariya2093@gmail.com', 'mobile_number': '058-2073', 'skills': ['Filing', 'Audit', 'Excel', 'Training', 'Word', 'Compliance', 'Ms excel', 'Regulations', 'Presentation', 'Partnership'], 'college_name': None, 'degree': None, 'designation': ['CS Executive'], 'experience': ['PROFESSIONAL QUALIFICATION:', 'Qualification', 'Marks (obtained)', 'CS Professional', 'CS Executive', 'CS Foundation', '481 / 900', '349 / 600', '200 / 400', 'WORK EXPERIENCE:', 'University/', 'Institute/ Board', 'ICSI', 'ICSI', 'ICSI', '\uf0d8 Completed  15  months  of  Apprenticeship  Training  under  Practicing', 'Company  Secretary Mr. Ashish Garg, Indore (Ex- President  of  ICSI)  from', 'January 2017 to April 2018.', '\uf0d8 Worked  as  a  Semi  Qualified  CS  under  Practicing  Company  Secretary  Firm,', '“Jeswani & Associates” Indore, from July, 2018 to March, 2019.', '\uf0d8 Worked  as  an  employee  under  the  Practicing  CA  Firm  “D  T  A  G  AND', 'ASSOCIATES”, 
# ...

# %%
print("Name:", data["name"])
print("Email:", data["email"])
print("Mobile Number:", data["mobile_number"])
print("Skills:", data["skills"])
print("College Name:", data["college_name"])
print("Degree:", data["degree"])
print("Designation:", data["designation"])
print("Company Names:", data["company_names"])
print("No Of Pages:", data["no_of_pages"])
print("Total Experience:", data["total_experience"])
# Out:
# Name: Alka Katariya
# Email: alkakatariya2093@gmail.com
# Mobile Number: 058-2073
# Skills: ['Filing', 'Audit', 'Excel', 'Training', 'Word', 'Compliance', 'Ms excel', 'Regulations', 'Presentation', 'Partnership']
# College Name: None
# Degree: None
# Designation: ['CS Executive']
# Company Names: ['CS Professional']
# No Of Pages: 3
# Total Experience: 1.25

# %%
import json

# %%
{
    "Name": "Tirth Vyas",
    "Email": "tirth3117@gmail.com",
    "Mobile Number": "9106714874",
    "Skills": [
        "Python", "Ai", "Scripting", "Instrumentation", "Operations", "Controls",
        "Design", "Segmentation", "Hardware", "Shell", "Policies", "Certification",
        "C", "Architectures", "Networking", "Database", "Rest", "Security",
        "Administration", "Ubuntu", "Linux", "Engineering", "Access", "Cloud",
        "Windows", "Sql", "System", "Mysql", "Github", "Website", "Architecture",
        "Aws", "Dhcp", "Oracle", "Improvement", "Documentation", "Technical",
        "Routing", "Dns", "Programming", "Cisco", "Servers", "Postgresql",
        "Installation"
    ],
    "College Name": "None",
    "Degree": ["Master’s of Computer Engineering"],
    "Designation": ["Linux Administrator Intern", "Cloud Engineer"],
    "Company Names": ["Amazon", "Oracle", "Cisco"],
    "No Of Pages": 1,
    "Total Experience": 0.42
}
# Out:
# {'Name': 'Tirth Vyas',
#  'Email': 'tirth3117@gmail.com',
#  'Mobile Number': '9106714874',
#  'Skills': ['Python',
#   'Ai',
#   'Scripting',
#   'Instrumentation',
#   'Operations',
#   'Controls',
#   'Design',
#   'Segmentation',
#   'Hardware',
#   'Shell',
#   'Policies',
#   'Certification',
#   'C',
#   'Architectures',
#   'Networking',
#   'Database',
#   'Rest',
#   'Security',
#   'Administration',
#   'Ubuntu',
#   'Linux',
#   'Engineering',
#   'Access',
#   'Cloud',
#   'Windows',
#   'Sql',
#   'System',
#   'Mysql',
#   'Github',
#   'Website',
#   'Architecture',
#   'Aws',
#   'Dhcp',
#   'Oracle',
#   'Improvement',
#   'Documentation',
#   'Technical',
#   'Routing',
#   'Dns',
#   'Programming',
#   'Cisco',
#   'Servers',
#   'Postgresql',
#   'Installation'],
#  'College Name': 'None',
#  'Degree': ['Master’s of Computer Engineering'],
#  'Designation': ['Linux Administrator Intern', 'Cloud Engineer'],
#  'Company Names': ['Amazon', 'Oracle', 'Cisco'],
# ...

# %%
import csv

# Define the list of users' data
data_list = [
    {
        'Name': 'Dhaval Pandya',
        'Email': 'dhaval.pandya80@gmail.com',
        'Mobile Number': '9879302163',
        'Skills': [
            'Analysis', 'Visual', 'Mysql', 'Documentation', 'English', 'Sql',
            'Communication', 'Oracle', 'C', 'Healthcare', 'Engineering', 'Api',
            'Email', 'Selenium', 'Automation', 'Jira', 'Technical',
            'Time management', 'System', 'Erp', 'Marketing', 'Testing',
            'Strategy', 'Conversion', 'Writing', 'Content', 'Ui', 'Tfs',
            'Reporting', 'Magic', 'Reports'
        ],
        'Degree': [
            'Post Graduate Diploma',
            'BE (Chemical) Bachelor of Engineering in Chemical'
        ],
        'Designation': [
            'Artist Touring Application - Artist Touring',
            'Manager',
            'Associate Delivery Manager',
            'Software Engineer'
        ],
        'Company Names': [
            'NetWeb Software Pvt. Ltd',
            'Civica Resource Pvt. Ltd.',
            'Sardar Patel',
            'Music',
            'dhaval.pandya80@gmail.com',
            'PriyaSharma Software Pvt. Ltd. (PSPL',
            'Magic Infocom Pvt. Ltd.'
        ]
    },
    {
    'Name': 'Tirth Vyas',
    'Email': 'tirth3117@gmail.com',
    'Mobile Number': '9106714874',
    'Skills': [
        'Python', 'Ai', 'Scripting', 'Instrumentation', 'Operations', 'Controls',
        'Design', 'Segmentation', 'Hardware', 'Shell', 'Policies', 'Certification', 'C',
        'Architectures', 'Networking', 'Database', 'Rest', 'Security', 'Administration',
        'Ubuntu', 'Linux', 'Engineering', 'Access', 'Cloud', 'Windows', 'Sql', 'System',
        'Mysql', 'Github', 'Website', 'Architecture', 'Aws', 'Dhcp', 'Oracle', 'Improvement',
        'Documentation', 'Technical', 'Routing', 'Dns', 'Programming', 'Cisco', 'Servers',
        'Postgresql', 'Installation'
    ],
    'College Name': 'None',
    'Degree': 'Master’s of Computer Engineering',
    'Designation': ['Linux Administrator Intern', 'Cloud Engineer'],
    'Company Names': ['Amazon', 'Oracle', 'Cisco'],
    'No Of Pages': 1,
    'Total Experience': 0.42
},
 {
    'Name': 'Vyas Sales',
    'Email': 'aadityavyas31@gmail.com',
    'Mobile Number': '429-2141',
    'Skills': [
        'Crm',
        'Digital marketing',
        'English',
        'Research',
        'Administration',
        'Photography',
        'Marketing',
        'Sales',
        'Chemicals',
        'Health'
    ],
    'College Name': 'None',
    'Degree': [
        'Bachelors of Business Administration in Marketing',
        'Masters of Business Administration in Marketing',
        'Post Graduate Program in Corporate Excellence (2024)'
    ],
    'Designation': [
        'Director',
        'Inside Sales Executive'
    ],
    'Company Names': [
        'Model United Nations (02/2019'
    ],
    'No Of Pages': 1,
    'Total Experience': 0.0
},
    {
    'Name': 'Aditya Chawla',
    'Email': 'chawla.aditya@gmail.com',
    'Mobile Number': '9811674094',
    'Skills': [
        'Brand',
        'Electrical',
        'Account management',
        'Matrix',
        'Analytical',
        'Operations',
        'Prospecting',
        'Proposal',
        'Communication',
        'C',
        'Health',
        'Schedules',
        'Legal',
        'Queries',
        'Kpis',
        'Contract management',
        'P',
        'R',
        'Negotiation',
        'Finance',
        'Sales operations',
        'Contracts',
        'Marketing',
        'Admissions',
        'Presentations',
        'Healthcare',
        'Retail',
        'Rfp',
        'Engineering',
        'English',
        'Cloud',
        'Forecasting',
        'Rfps',
        'System',
        'Sales',
        'Electronics',
        'Process',
        'Technical',
        'Invoicing',
        'Responses'
    ],
    'College Name': 'None',
    'Degree': [
        'MBA',
        'B.Tech'
    ],
    'Designation': [
        'Account Manager',
        'Business Development',
        'Assistant Manager Marketing'
    ],
    'Company Names': [
        'Client Relationships',
        'Wipro Infotech'
    ],
    'No Of Pages': 2,
    'Total Experience': 0.0
},
{
    'Name': 'Atharv Kokane',
    'Email': 'atharvkokane95@gmail.com',
    'Mobile Number': '7741857515',
    'Skills': [
        'Transport',
        'Analytical',
        'Java',
        'Certification',
        'Communication',
        'Database',
        'Beverage',
        'Administration',
        'Os',
        'Troubleshooting',
        'Linux',
        'English',
        'Api',
        'Windows',
        'System',
        'Excel',
        'Sap',
        'Training',
        'Agile',
        'Technical',
        'Installation'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 1,
    'Total Experience': 0.0
},
    {
    'Name': 'Linux System',
    'Email': 'darshanbarot66@gmail.com',
    'Mobile Number': '7874657957',
    'Skills': [
        'Certification',
        'Networking',
        'Security',
        'Administration',
        'Protocols',
        'Docker',
        'Os',
        'Migration',
        'Troubleshooting',
        'Ubuntu',
        'Linux',
        'Distribution',
        'Redhat',
        'Windows',
        'System',
        'Lan',
        'Dhcp',
        'Training',
        'Unix',
        'Dns',
        'Operating systems',
        'Vmware',
        'Servers',
        'Installation'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 2,
    'Total Experience': 0
},
    {
    'Name': 'CURRICULUM VITAE',
    'Email': 'Devanshacharya1996@gmail.com',
    'Mobile Number': '380054 8209',
    'Skills': [
        'Engineering',
        'Sourcing',
        'English',
        'Recruitment',
        'Training',
        'Hospital',
        'Technical',
        'Recruit',
        'System',
        'Staffing',
        'Programming',
        'Telecom',
        'Healthcare',
        'C++',
        'C',
        'Compliance'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 3,
    'Total Experience': 8.08
},
    {
    'Name': 'Foram Sarda',
    'Email': 'foramsarda1997@gmail.com',
    'Mobile Number': '7383753560',
    'Skills': [
        'Sap',
        'Crm',
        'English',
        'Access',
        'Database',
        'Oracle',
        'Scheduling',
        'Administration',
        'System',
        'Windows',
        'Analysis',
        'Os',
        'Mysql',
        'Troubleshooting',
        'Installation',
        'Linux',
        'Health'
    ],
    'College Name': 'None',
    'Degree': [
        'Degree',
        'M.C.A',
        'D-O-B',
        'B.C.A'
    ],
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 4,
    'Total Experience': 0.0
},
    {
    'Name': 'Harsh Patel',
    'Email': 'harshmp44@gmail.com',
    'Mobile Number': '8141343299',
    'Skills': [
        'Itil',
        'Sap',
        'Transport',
        'Reports',
        'Database',
        'Process',
        'Research',
        'Erp',
        'Security',
        'Administration',
        'System',
        'Db2',
        'Troubleshooting'
    ],
    'College Name': 'None',
    'Degree': [
        'B.E. Automobile'
    ],
    'Designation': 'None',
    'Company Names': [
        'SAP BASIS & SECURITY CONSULTANT'
    ],
    'No Of Pages': 1,
    'Total Experience': 0.0
},
    {
    'Name': 'Karthik Dixith',
    'Email': 'dixith2020@gmail.com',
    'Mobile Number': '8123305542',
    'Skills': [
        'Software development life cycle',
        'Payments',
        'Specifications',
        'Scheduling',
        'Analyze',
        'Analytical',
        'Design',
        'Communication',
        'Test plans',
        'Process improvement',
        'Pivot',
        'Security',
        'Engineering',
        'Schedule',
        'Testing',
        'Debugging',
        'Windows',
        'Sql',
        'System',
        'Jira',
        'Technical skills',
        'Automation',
        'Workflow',
        'Electronics',
        'Architecture',
        'Training',
        'Process',
        'Documentation',
        'Improvement',
        'Agile',
        'Scrum',
        'Technical',
        'Operating systems',
        'Responses'
    ],
    'College Name': 'None',
    'Degree': [
        'Bachelors in engineering'
    ],
    'Designation': [
        'Support Associate in Speridian Technologies',
        'Senior Software Engineer',
        'SENIOR RPA DEVELOPER'
    ],
    'Company Names': 'None',
    'No Of Pages': 4,
    'Total Experience': 0.0
},
    {
    'Name': 'Gujarat Keyurpanchal0017@gmail.com',
    'Email': 'Keyurpanchal0017@gmail.com',
    'Mobile Number': '9173615370',
    'Skills': [
        'Word',
        'Improvement',
        'Excel',
        'Analysis',
        'Pharmaceutical',
        'Tax',
        'Audit',
        'Accounting',
        'Compliance'
    ],
    'College Name': 'None',
    'Degree': [
        'B.COM'
    ],
    'Designation': [
        'Assistant Specialist in Accounting',
        'Account Assistant & Audit'
    ],
    'Company Names': 'None',
    'No Of Pages': 1,
    'Total Experience': 7.25
},
    {
    'Name': 'MAYANK KUMAR',
    'Email': 'Mayankkumar8520@gmail.com',
    'Mobile Number': '7301877460',
    'Skills': [
        'Engineering',
        'Sap',
        'English',
        'Reports',
        'Database',
        'Schedule',
        'Process',
        'Scheduling',
        'Security',
        'Administration',
        'System',
        'Analysis',
        'Java',
        'Audit',
        'Troubleshooting',
        'Installation',
        'Health'
    ],
    'College Name': 'None',
    'Degree': [
        'Bachelor of Technology CGPA- 7.74'
    ],
    'Designation': [
        'System Engineer in Tata Consultancy Services',
        'SAP Basis Administrator'
    ],
    'Company Names': 'None',
    'No Of Pages': 2,
    'Total Experience': 2.58
},
    {
    'Name': 'Parag Somani',
    'Email': 'paragsomani@gmail.com',
    'Mobile Number': '9893324959',
    'Skills': [
        'Transactions',
        'Sql server',
        'Fda',
        'Apis',
        'Safety',
        'Operations',
        'Design',
        'Inventory',
        'Certification',
        'C',
        'Architectures',
        'Health',
        'Queries',
        'Inventory management',
        'Asp',
        'Requests',
        'Api',
        'Erp',
        'Testing',
        'Windows',
        'Sql',
        'System',
        'Iso',
        'Sales',
        'Automation',
        'Pharmacy',
        'Website',
        'Product management',
        'Compliance',
        'Architecture',
        'Sap',
        'Tfs',
        'Reports',
        'Scrum',
        'Documentation',
        'Process',
        'Agile',
        'Technical',
        'Regulations',
        'Workflows'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 3,
    'Total Experience': 0.0
},
    {
    'Name': 'Parag Somani',
    'Email': 'paragsomani@gmail.com',
    'Mobile Number': '9893324959',
    'Skills': [
        'Transactions',
        'Sql server',
        'Fda',
        'Apis',
        'Safety',
        'Operations',
        'Design',
        'Inventory',
        'Certification',
        'C',
        'Architectures',
        'Health',
        'Queries',
        'Inventory management',
        'Asp',
        'Requests',
        'Api',
        'Erp',
        'Testing',
        'Windows',
        'Sql',
        'System',
        'Iso',
        'Sales',
        'Automation',
        'Pharmacy',
        'Website',
        'Product management',
        'Compliance',
        'Architecture',
        'Sap',
        'Tfs',
        'Reports',
        'Scrum',
        'Documentation',
        'Process',
        'Agile',
        'Technical',
        'Regulations',
        'Workflows'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 3,
    'Total Experience': 0.0
},
    {
    'Name': 'M A',
    'Email': 'rituverma81@yahoo.com',
    'Mobile Number': '9818384999',
    'Skills': [
        'Content',
        'Transactions',
        'Engagement',
        'Kpi',
        'Strategy',
        'Ios',
        'Ai',
        'Operations',
        'Policies',
        'Communication',
        'C',
        'Vendors',
        'Governance',
        'P',
        'R',
        'Finance',
        'Process improvements',
        'Contracts',
        'Mining',
        'Application support',
        'Mobile',
        'Presentations',
        'Data management',
        'Continuous improvement',
        'Retail',
        'Rfp',
        'Supply chain management',
        'Apex',
        'Analytics',
        'Requests',
        'English',
        'Lean',
        'Android',
        'System',
        'Sops',
        'Updates',
        'Analysis',
        'Alliances',
        'Sales',
        'Customer experience',
        'Automation',
        'Email',
        'Quality standards',
        'Pmp',
        'Resource management',
        'Compliance',
        'Itil',
        'Improvement',
        'Process',
        'Training',
        'Banking',
        'Documentation',
        'Ibm',
        'Technical',
        'Project planning',
        'Data analysis'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': [
        'Team Leader',
        'Sr. Team Leader',
        'Team Member',
        'Assistant Manager',
        'Deputy Manager',
        'Project Manager',
        'Application Development'
    ],
    'Company Names': 'None',
    'No Of Pages': 3,
    'Total Experience': 0.0
},
    {
    'Name': 'Sarika Jadhav',
    'Email': 'jadhavsarika425@gmail.com',
    'Mobile Number': '8208408559',
    'Skills': [
        'Desktop support',
        'Hardware',
        'Inventory',
        'Certification',
        'Communication',
        'Health',
        'Administration',
        'Mobile',
        'Os',
        'Migration',
        'Troubleshooting',
        'Linux',
        'Engineering',
        'English',
        'Access',
        'Cloud',
        'Windows',
        'System',
        'Sql',
        'Email',
        'Sap',
        'Dhcp',
        'Process',
        'Technical',
        'Dns',
        'Presentation',
        'Vmware',
        'Servers',
        'Installation'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 4,
    'Total Experience': 0.0
},
    {
    'Name': 'Shivanjali Bhorhari',
    'Email': 'bhorharishivanjali@gmail.com',
    'Mobile Number': '9174005235',
    'Skills': [
        'Sap',
        'Aws',
        'Oracle',
        'Database',
        'Technical',
        'Windows',
        'System',
        'Administration',
        'Analysis',
        'Java',
        'Servers',
        'Troubleshooting',
        'Communication',
        'Linux'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 1,
    'Total Experience': 0.0
},
    {'Name': 'IELTS GENERAL',
 'Email': 'monali16296@gmail.com',
 'Mobile Number': '9195743657',
 'Skills': ['Apis',
  'Tax',
  'Php',
  'C++',
  'Java',
  'Communication',
  'C',
  'Js',
  'Database',
  'Html5',
  'Plan',
  'Engineering',
  'Video',
  'English',
  'Api',
  'System',
  'Sql',
  'Technical skills',
  'Visual',
  'Aws',
  'Training',
  'Scrum',
  'Technical',
  'International',
  'Css'],
 'College Name': 'None',
 'Degree': 'None',
 'Designation': ['Software Engineer', 'Sr. Software Engineer'],
 'Company Names': 'None',
 'No Of Pages': 3,
 'Total Experience': 0.0
     },

    {
        'Name': 'RPA Developer',
        'Email': 'Dishalunagariya9@gmail.com',
        'Mobile Number': '7021564427',
        'Skills': [
            'Excel', 'Architecture', 'Email', 'Programming', 'English', 'Workflows',
            'Sql', 'Debugging', 'Process', 'Database', 'Analytical', 'Gmail',
            'Workflow', 'C', 'Training', 'Strong analytical skills', 'Automation',
            'Access', 'Website'
        ],
        'College Name': 'None',
        'Degree': 'None',
        'Designation': 'None',
        'Company Names': ['PMS Process Automation'],
        'No Of Pages': 2,
        'Total Experience': 1.25
    },
    {
        'Name': 'Krishika Raol',
        'Email': 'krishika0702@gmail.com',
        'Mobile Number': '017 2017',
        'Skills': [
            'Github', 'Communication', 'Css', 'Api', 'Javascript', 'Java',
            'Wordpress', 'Responses', 'Technical', 'Programming', 'Access',
            'Algorithms', 'Database', 'Html'
        ],
        'College Name': 'None',
        'Degree': 'None',
        'Designation': 'None',
        'Company Names': 'None',
        'No Of Pages': 1,
        'Total Experience': 0.0
    },
    {
        'Name': 'NEERAV SINGH',
        'Email': 'neerav_its@rediffmail.com',
        'Mobile Number': '9810849353',
        'Skills': [
            'Transactions', 'Sql server', 'Specifications', 'Apis', 'Scheduling',
            'Regulatory requirements', 'Matrix', 'C#', 'Controls', 'Operations',
            'Design', 'Inventory', 'Hardware', 'Real-time', 'Communication',
            'Certification', 'C', 'Architectures', 'Java', 'Health', 'Vendors',
            'Database', 'P', 'R', 'Finance', 'Writing', 'Html', 'Security',
            'Solution architecture', 'Retail', 'Economics', 'Troubleshooting',
            'Coding', 'Consulting', 'Ansible', 'English', 'Access', 'Cloud',
            'Api', 'Erp', 'Testing', 'Regulatory', 'Sql', 'System', '.net',
            'Analysis', 'Jira', 'Sales', 'Vendor management', 'Mysql', 'Github',
            'Architecture', 'Sap', 'Aws', 'Tfs', 'Reports', 'Scrum', 'Agile',
            'Process', 'Technical', 'Tableau', 'Payroll', 'Pdf', 'Banking',
            'Quality control', 'Sdlc', 'Programming', 'Reporting', 'Workflows'
        ],
        'College Name': 'None',
        'Degree': 'None',
        'Designation': 'None',
        'Company Names': 'None',
        'No Of Pages': 7,
        'Total Experience': 1.42
    },
    {
        'Name': 'Manish Asodariya',
        'Email': 'asodariyamanish@gmail.com',
        'Mobile Number': '360022 9724',
        'Skills': [
            'Operations', 'Php', 'Design', 'Hardware', 'Networking', 'Database',
            'Security', 'Administration', 'Docker', 'Os', 'Migration',
            'Troubleshooting', 'Ubuntu', 'Linux', 'Consulting', 'English',
            'Access', 'Cloud', 'Erp', 'Windows', 'System', 'Budget', 'Sql',
            'Lifecycle', 'Jira', 'Email', 'Mysql', 'Website', 'Github',
            'Architecture', 'Aws', 'Sap', 'Hospital', 'Dhcp', 'Technical',
            'Ibm', 'Dns', 'Vmware', 'Cms', 'Cisco', 'Servers', 'Installation'
        ],
        'College Name': 'None',
        'Degree': ['Bachelor of Arts'],
        'Designation': [
            'Sr. Consultant', 'System Administrator', 'Deputy Manager',
            'Systems Engineer', 'Endpoint Protection Manager'
        ],
        'Company Names': [
            'Kunal Structure India Pvt. Ltd',
            'SAP Bone',
            'Evolution Infosystem Pvt Ltd'
        ],
        'No Of Pages': 3,
        'Total Experience': 0
    },
    {
    'Name': 'CS Sanchita K. Ojha',
    'Email': 'sanchitaojha227@gmail.com',
    'Mobile Number': '9913275531',
    'Skills': [
        'English', 'Filing', 'Compliance', 'Process', 'Security', 'Communication',
        'Migration', 'Conversion', 'Regulations'
    ],
    'College Name': 'None',
    'Degree': ['B. Com, LLB'],
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 4,
    'Total Experience': 0.0
},
    {
    'Name': 'Pawan Panjwani',
    'Email': 'pawan.panjwani@spglobal.com',
    'Mobile Number': '012-2014',
    'Skills': [
        'Modeling', 'Communication', 'Finance', 'Database', 'Python', 'Training',
        'Tableau', 'Financial models', 'Agile', 'Recruitment', 'Process', 'Analytics',
        'Automation', 'C', 'R', 'P', 'Outreach', 'Salesforce', 'Excel', 'Lean',
        'Queries', 'Sql', 'Plan', 'Business process', 'Testing', 'Technical', 'Programming'
    ],
    'College Name': 'None',
    'Degree': ['Arts & Commerce', 'Gradution in Commerce', 'MBA in Finance'],
    'Designation': 'None',
    'Company Names': ['Vedlogic Solutions Pvt. Ltd.'],
    'No Of Pages': 2,
    'Total Experience': 0.0
},
    {
    'Name': 'Vankadi Paras',
    'Email': 'vankadi.paras1895@gmail.com',
    'Mobile Number': '9904797849',
    'Skills': [
        'Jira', 'Ubuntu', 'Ansible', 'Design', 'Aws', 'Docker', 'Engagement',
        'Lifecycle', 'Technical skills', 'Payments', 'Cloud', 'Documentation',
        'Postgresql', 'Testing', 'Scripting', 'Rest', 'Mysql', 'Compliance',
        'English', 'Selenium', 'Mobile', 'Sourcing', 'Programming', 'Javascript',
        'Automation', 'Java', 'Js', 'Technical', 'Shell', 'System', 'Windows',
        'Analysis', 'Analytical', 'Apis', 'Security', 'Api'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': ['Computer Engineer'],
    'Company Names': 'None',
    'No Of Pages': 3,
    'Total Experience': 0.0
},
    {
    'Name': 'Bhavesh Prajapati',
    'Email': 'Bhavesh8121994@gmail.com',
    'Mobile Number': '9558239022',
    'Skills': [
        'Computer science', 'Ordering', 'Design', 'Oracle', 'Threading', 'Coding',
        'Requests', 'Aws', 'Process', 'Html5', 'Profiling', 'Documentation',
        'Jsp', 'Postgresql', 'Specifications', 'Testing', 'Github', 'Mysql',
        'Logging', 'C', 'Governance', 'Javascript', 'Automation', 'Agile',
        'Java', 'Js', 'Sdlc', 'Technical', 'Communication', 'Engineering',
        'System', 'Shell', 'Photography', 'Analysis', 'Security', 'Api'
    ],
    'College Name': 'None',
    'Degree': [
        'Bhavesh8121994@gmail.com', 'Diploma Computer Engineer'
    ],
    'Designation': [
        'Software Engineer', 'B.E Computer Engineering'
    ],
    'Company Names': [
        'Staunchsys it services Pvt Ltd', 'PROFILE SUMMARY',
        'Nascent Info Technologies Pvt Ltd'],
'No Of Pages': 2,
    'Total Experience': 3.25
},
    {
    'Name': 'None',
    'Email': 'None',
    'Mobile Number': 'None',
    'Skills': [],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 'None',
    'Total Experience': 0
},
    {
    'Name': 'CURRICULUM VITAE',
    'Email': 'Devanshacharya1996@gmail.com',
    'Mobile Number': '380054 8209',
    'Skills': [
        'Training', 'Telecom', 'Recruitment', 'Hospital', 'Engineering', 'Compliance',
        'System', 'Recruit', 'English', 'Sourcing', 'Programming', 'C++',
        'Healthcare', 'Technical', 'Staffing', 'C'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': 'None',
    'Company Names': 'None',
    'No Of Pages': 3,
    'Total Experience': 8.08
},
    {
    'Name': 'Parag Somani',
    'Email': 'paragsomani@gmail.com',
    'Mobile Number': '9893324959',
    'Skills': [
        'Workflows', 'Scrum', 'Sql server', 'Architecture', 'Safety', 'Health',
        'Design', 'Requests', 'Process', 'Sap', 'Iso', 'Reports', 'Certification',
        'Documentation', 'Inventory management', 'Tfs', 'Erp', 'Testing',
        'Inventory', 'Compliance', 'C', 'Architectures', 'Operations', 'Website',
        'Pharmacy', 'Queries', 'Sql', 'Automation', 'Agile', 'Transactions',
        'Technical', 'Asp', 'Fda', 'System', 'Windows', 'Product management',
        'Apis', 'Sales', 'Api', 'Regulations'
    ],
    'College Name': 'None',
    'Degree': 'None',
    'Designation': [
        'Senior Software Engineer',
        'Support Specialist (Global Technical Support)',
        'Product Architect'
    ],
    'Company Names': 'None',
    'No Of Pages': 3,
    'Total Experience': 0.0
},
    {
    'Name': 'Pawan Panjwani',
    'Email': 'pawan.panjwani@spglobal.com',
    'Mobile Number': '012-2014',
    'Skills': [
        'P', 'Finance', 'Outreach', 'Process', 'Salesforce', 'Training', 'Excel',
        'Testing', 'Analytics', 'Database', 'Tableau', 'C', 'Modeling',
        'Recruitment', 'Python', 'Queries', 'Programming', 'Automation', 'Sql',
        'Agile', 'Financial models', 'Lean', 'Technical', 'Communication',
        'Business process', 'Plan', 'R'
    ],
    'College Name': 'None',
    'Degree': [
        'Arts & Commerce',
        'Gradution in Commerce',
        'MBA in Finance'
    ],
    'Designation': 'None',
    'Company Names': ['Vedlogic Solutions Pvt. Ltd.'],
    'No Of Pages': 2,
    'Total Experience': 0.0
}






]



















# Define the CSV file path
file_path = '/content/drive/MyDrive/Resume parsing resumes/combined_info.csv'

# Write the data to a CSV file
with open(file_path, mode='w', newline='') as file:
    writer = csv.writer(file)

    # Write the header using the keys of the first dictionary
    header = data_list[0].keys()
    writer.writerow(header)

    # Write the data rows
    for data in data_list:
        writer.writerow([
            data['Name'],
            data['Email'],
            data['Mobile Number'],
            ', '.join(data['Skills']),
            ', '.join(data['Degree']),
            ', '.join(data['Designation']),
            ', '.join(data['Company Names'])
        ])

print(f"Data has been written to {file_path}")
# Out:
# Data has been written to /content/drive/MyDrive/Resume parsing resumes/combined_info.csv

# %%
pip install requests

# %%
import requests

# Define the URL to which the POST request will be sent
url = "https://raj-sttl-resumeapi-development1-14228198.dev.odoo.com/api/add-resume"

# Define the updated request body
request_body = {
    "application_name": "",
    "applicant_name": "Alka Katariya",
    "email": "alkakatariya2093@gmail.com",
    "description": "Filing, Audit, Excel, Training, Word, Compliance, Ms excel, Regulations, Presentation, Partnership",
    "mobile": "058-2073",
    "job": "CS Executive",
    "department": "",
    "degree": "None",
    "company": "CS Professional",
    "no_of_pages": 3,
    "total_experience": 1.25
}

# Function to send the POST request with SSL verification disabled
def send_post_request(url, data):
    try:
        response = requests.post(url, json=data, verify=False)  # Disable SSL verification
        response.raise_for_status()  # Raise an exception for HTTP errors
        print("POST request successful!")
        print("Response Status Code:", response.status_code)
        print("Response Body:", response.json())
    except requests.exceptions.RequestException as e:
        print("POST request failed:", e)

# Sending the POST request
send_post_request(url, request_body)
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'raj-sttl-resumeapi-development1-14228198.dev.odoo.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.odoo.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# POST request successful!
# Response Status Code: 200
# POST request failed: Expecting value: line 1 column 1 (char 0)
